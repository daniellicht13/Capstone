# %%
pip install ccxt
# Out:
# Requirement already satisfied: ccxt in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (1.34.54)
# Requirement already satisfied: aiodns==1.1.1; python_version >= "3.5.2" in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from ccxt) (1.1.1)
# Requirement already satisfied: requests>=2.18.4 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from ccxt) (2.24.0)
# Requirement already satisfied: yarl==1.1.0; python_version >= "3.5.2" in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from ccxt) (1.1.0)
# Requirement already satisfied: cryptography>=2.6.1 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from ccxt) (2.9.2)
# Requirement already satisfied: certifi>=2018.1.18 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from ccxt) (2020.6.20)
# Requirement already satisfied: aiohttp==3.6.2; python_version >= "3.5.2" in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from ccxt) (3.6.2)
# Requirement already satisfied: setuptools>=38.5.1 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from ccxt) (49.2.0.post20200714)
# Requirement already satisfied: pycares>=1.0.0 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from aiodns==1.1.1; python_version >= "3.5.2"->ccxt) (3.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.18.4->ccxt) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.18.4->ccxt) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.18.4->ccxt) (1.25.9)
# Requirement already satisfied: multidict>=4.0 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from yarl==1.1.0; python_version >= "3.5.2"->ccxt) (4.7.6)
# Requirement already satisfied: six>=1.4.1 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from cryptography>=2.6.1->ccxt) (1.15.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from cryptography>=2.6.1->ccxt) (1.14.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from aiohttp==3.6.2; python_version >= "3.5.2"->ccxt) (3.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from aiohttp==3.6.2; python_version >= "3.5.2"->ccxt) (19.3.0)
# Requirement already satisfied: pycparser in /Users/daniellicht/opt/anaconda3/lib/python3.8/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.6.1->ccxt) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ccxt
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
exch = 'binance' # initial exchange
t_frame = '1d' # 1-day timeframe, usually from 1-minute to 1-week depending on the exchange
symbol = 'ADA/BTC' # initial symbol
exchange_list = ['binance','bitfinex','kraken','poloniex']
 
# Get our Exchange
try:
    exchange = getattr (ccxt, exch) ()
except AttributeError:
    print('-'*36,' ERROR ','-'*35)
    print('Exchange "{}" not found. Please check the exchange is supported.'.format(exch))
    print('-'*80)
    quit()
 
# Check if fetching of OHLC Data is supported
if exchange.has["fetchOHLCV"] != True:
    print('-'*36,' ERROR ','-'*35)
    print('{} does not support fetching OHLC data. Please use another  exchange'.format(exch))
    print('-'*80)
    quit()
 
# Check requested timeframe is available. If not return a helpful error.
if (not hasattr(exchange, 'timeframes')) or (t_frame not in exchange.timeframes):
    print('-'*36,' ERROR ','-'*35)
    print('The requested timeframe ({}) is not available from {}\n'.format(t_frame,exch))
    print('Available timeframes are:')
    for key in exchange.timeframes.keys():
        print('  - ' + key)
    print('-'*80)
    quit()
 
# Check if the symbol is available on the Exchange
exchange.load_markets()
if symbol not in exchange.symbols:
    print('-'*36,' ERROR ','-'*35)
    print('The requested symbol ({}) is not available from {}\n'.format(symbol,exch))
    print('Available symbols are:')
    for key in exchange.symbols:
        print('  - ' + key)
    print('-'*80)
    quit()

# %%
# Get data
data = exchange.fetch_ohlcv(symbol, t_frame)
header = ['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume']
df = pd.DataFrame(data, columns=header).set_index('Timestamp')
df['symbol'] = symbol
syms = [symbol]
filename = '{}.csv'.format(t_frame)
exchange_map = defaultdict(list)
for exch in exchange_list:
    try:
        exchange = getattr (ccxt, exch) ()
    except AttributeError:
        print('-'*36,' ERROR ','-'*35)
        print('Exchange "{}" not found. Please check the exchange is supported.'.format(exch))
        print('-'*80)
        quit()
    if exchange.has["fetchOHLCV"] != True:
        print('-'*36,' ERROR ','-'*35)
        print('{} does not support fetching OHLC data. Please use another exchange'.format(exch))
        print('-'*80)
        quit()
    if (not hasattr(exchange, 'timeframes')) or (t_frame not in exchange.timeframes):
        print('-'*36,' ERROR ','-'*35)
        print('The requested timeframe ({}) is not available from {}\n'.format(t_frame,exch))
        print('Available timeframes are:')
        for key in exchange.timeframes.keys():
            print('  - ' + key)
        print('-'*80)
        quit()
    exchange.load_markets()
    for coin in exchange.symbols:
        if coin in syms or coin[-3:] != 'BTC':
            continue
        else:
            try:
                data = exchange.fetch_ohlcv(coin, t_frame)
            except:
                continue
            data_df = pd.DataFrame(data, columns=header).set_index('Timestamp')
            data_df['symbol'] = coin
            df = df.append(data_df)
            syms.append(coin)
            exchange_map[exch] = [pd.to_datetime(data_df.index/1000, unit='s'), data_df.Close]
df.index = df.index/1000 #Timestamp is 1000 times bigger than it should be in this case
df['Date'] = pd.to_datetime(df.index,unit='s')

# %%
df
# Out:
#                   Open      High       Low     Close        Volume    symbol  \
# Timestamp
# 1.558138e+09  0.000011  0.000012  0.000011  0.000011  1.584155e+08   ADA/BTC
# 1.558224e+09  0.000011  0.000011  0.000011  0.000011  1.818711e+08   ADA/BTC
# 1.558310e+09  0.000011  0.000011  0.000010  0.000011  2.430554e+08   ADA/BTC
# 1.558397e+09  0.000011  0.000011  0.000010  0.000011  1.602646e+08   ADA/BTC
# 1.558483e+09  0.000011  0.000011  0.000010  0.000010  1.923128e+08   ADA/BTC
# ...                ...       ...       ...       ...           ...       ...
# 1.600906e+09  0.003964  0.004030  0.003823  0.003911  1.471476e+02  XFIL/BTC
# 1.600992e+09  0.003911  0.003911  0.003823  0.003853  3.811099e+01  XFIL/BTC
# 1.601078e+09  0.003853  0.003853  0.003823  0.003839  5.370793e+01  XFIL/BTC
# 1.601165e+09  0.003839  0.003857  0.003823  0.003840  3.641176e+01  XFIL/BTC
# 1.601251e+09  0.003840  0.003840  0.003823  0.003840  3.204899e+01  XFIL/BTC
#
#                    Date
# Timestamp
# 1.558138e+09 2019-05-18
# 1.558224e+09 2019-05-19
# 1.558310e+09 2019-05-20
# 1.558397e+09 2019-05-21
# 1.558483e+09 2019-05-22
# ...                 ...
# 1.600906e+09 2020-09-24
# 1.600992e+09 2020-09-25
# 1.601078e+09 2020-09-26
# 1.601165e+09 2020-09-27
# 1.601251e+09 2020-09-28
#
# [94770 rows x 7 columns]

# %%
for exch in exchange_map:
    plt.plot(exchange_map[exch][0], exchange_map[exch][1])

# %%
exchange_map["binance"][1]
# Out:
# Timestamp
# 1558137600000    0.000045
# 1558224000000    0.000041
# 1558310400000    0.000040
# 1558396800000    0.000042
# 1558483200000    0.000040
#                    ...
# 1600905600000    0.000036
# 1600992000000    0.000038
# 1601078400000    0.000036
# 1601164800000    0.000037
# 1601251200000    0.000038
# Name: Close, Length: 500, dtype: float64
